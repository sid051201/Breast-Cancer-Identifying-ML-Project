# %% [markdown]
# # Using Machine Learning to Identify Benin or Malignant Breast Cancers

# %%
# Importing Necessary Libraries and dataset
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

data = pd.read_csv(r'cancer_data.csv')

# %% [markdown]
# ## Exploratory Data Analysis

# %%
data.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
print(data.isnull().sum())
print(data['Unnamed: 32']) # There seems to be an unnamed column which doesn't provide any important data - we can ignore it
# Out:
# id                           0
# diagnosis                    0
# radius_mean                  0
# texture_mean                 0
# perimeter_mean               0
# area_mean                    0
# smoothness_mean              0
# compactness_mean             0
# concavity_mean               0
# concave points_mean          0
# symmetry_mean                0
# fractal_dimension_mean       0
# radius_se                    0
# texture_se                   0
# perimeter_se                 0
# area_se                      0
# smoothness_se                0
# compactness_se               0
# concavity_se                 0
# concave points_se            0
# symmetry_se                  0
# fractal_dimension_se         0
# radius_worst                 0
# texture_worst                0
# perimeter_worst              0
# area_worst                   0
# smoothness_worst             0
# compactness_worst            0
# concavity_worst              0
# concave points_worst         0
# ...

# %%
# Create your countplot
sns.set(style="whitegrid")
plt.figure(figsize=(8, 6))
ax = sns.countplot(data=data, x='diagnosis')

# Add count values on top of the bars
for p in ax.patches:
    ax.annotate(f'{p.get_height()}', (p.get_x() + p.get_width() / 2., p.get_height()),
                ha='center', va='center', fontsize=12, color='black', xytext=(0, 5),
                textcoords='offset points')

# Customize labels and title
ax.set_xlabel("Diagnosis", fontsize=14)
ax.set_ylabel("Count", fontsize=14)
ax.set_title("Diagnosis Count", fontsize=16)

# Show the plot
plt.show()

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[17], line 3
#       1 # Creating a PairPlot to identify any correlations
# ----> 3 sns.pairplot(data = data)
#
# File ~\anaconda3\lib\site-packages\seaborn\axisgrid.py:2158, in pairplot(data, hue, hue_order, palette, vars, x_vars, y_vars, kind, diag_kind, markers, height, aspect, corner, dropna, plot_kws, diag_kws, grid_kws, size)
#    2156 if kind == "scatter":
#    2157     from .relational import scatterplot  # Avoid circular import
# -> 2158     plotter(scatterplot, **plot_kws)
#    2159 elif kind == "reg":
#    2160     from .regression import regplot  # Avoid circular import
#
# File ~\anaconda3\lib\site-packages\seaborn\axisgrid.py:1421, in PairGrid.map_offdiag(self, func, **kwargs)
#    1419     self.map_lower(func, **kwargs)
#    1420     if not self._corner:
# -> 1421         self.map_upper(func, **kwargs)
# ...
